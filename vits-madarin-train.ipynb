# %%
# 查看显卡
# !nvidia-smi
# Out:
# +--------------------------------------------------------------------------------------------+
# | ORION-SMI 1.0             Time: 2023-02-19 21:25:12            CUDA Version: N/A           |
# +-----------------------------------------------+----------------------+---------------------+
# | IP               vGPU Name       Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC|
# | pGPU  vGPU       Physical GPU Name            |         Memory-Usage | GPU-Util  Compute M.|
# |===============================================+======================+=====================|
# | 0.0.0.0          Orion vGPU              Off  |   N/A            Off |                 N/A |
# |  0     0         Orion-vGPU                   |      0MiB /  8000MiB |      0%     Default |
# +--------------------------------------------------------------------------------------------+
#
# +--------------------------------------------------------------------------------------------+
# ...

# %%
#@title 克隆github仓库
# !git clone https://github.com/Zedtion/vits-Chinese
# Out:
# Cloning into 'vits-Chinese'...
# remote: Enumerating objects: 645, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 645 (delta 3), reused 9 (delta 3), pack-reused 628
# Receiving objects: 100% (645/645), 31.32 MiB | 8.26 MiB/s, done.
# Resolving deltas: 100% (299/299), done.

# %%
#@title 安装依赖
# %cd ./vits-Chinese
# !pip install -r requirements.txt
# Out:
# [Errno 2] No such file or directory: './vits-Chinese'
# /root/vits-Chinese
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/, https://mirrors.aliyun.com/pypi/simple/
# Requirement already up-to-date: Cython==0.29.21 in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (0.29.21)
# Requirement already up-to-date: librosa==0.8.0 in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.8.0)
# Requirement already up-to-date: matplotlib==3.3.1 in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (3.3.1)
# Requirement already up-to-date: numpy==1.21.6 in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.21.6)
# ...

# %%
#@ 数据集拷贝到项目根目录并解压
# !cp ~/data/user/Caitlyn-vits/wavs.zip ~/vits-Chinese
# !unzip wavs.zip
# Out:
# Archive:  wavs.zip
#   inflating: wavs/File0001_0000.wav
#   inflating: wavs/File0002_0000.wav
#   inflating: wavs/File0003_0000.wav
#   inflating: wavs/File0004_0000.wav
#   inflating: wavs/File0007_0000.wav
#   inflating: wavs/File0008_0000.wav
#   inflating: wavs/File0009_0000.wav
#   inflating: wavs/File0010_0000.wav
#   inflating: wavs/File0011_0000.wav
#   inflating: wavs/File0012_0000.wav
#   inflating: wavs/File0013_0000.wav
#   inflating: wavs/File0014_0000.wav
#   inflating: wavs/File0015_0000.wav
#   inflating: wavs/File0016_0000.wav
#   inflating: wavs/File0017_0000.wav
#   inflating: wavs/File0018_0000.wav
#   inflating: wavs/File0020_0000.wav
#   inflating: wavs/File0021_0000.wav
#   inflating: wavs/File0022_0000.wav
#   inflating: wavs/File0023_0000.wav
#   inflating: wavs/File0025_0000.wav
#   inflating: wavs/File0026_0000.wav
#   inflating: wavs/File0027_0000.wav
#   inflating: wavs/File0028_0000.wav
#   inflating: wavs/File0029_0000.wav
# ...

# %%
#@ 数据预处理（训练集、验证集）
# !python shuffle_list.py
# !python preprocess.py
# Out:
# START: filelists/list_val.txt
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.929 seconds.
# DEBUG:jieba:Loading model cost 0.929 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# START: filelists/list.txt

# %%
#@ 训练模型
# !python train.py -c .configs\chinese_base.json -m Caitlyn
